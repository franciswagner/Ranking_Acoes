# 2021-07-12  4.840000      5.57  127594.0
# 2021-07-13  4.890000      5.57  128168.0
# 2021-07-14  4.830000      5.65  128407.0
#
# [389 rows x 256 columns]

# %% [markdown]
# ## Filtrando para últimas 260 observações

# %%
dados = dados.tail(260)

# %% [markdown]
# ## Filtrando ações com liquidez baixa

# %%
liquidez_desejada = 1 
for a in acoes:
    print(f'Checando liquidez da {a}')
    if dados[a].describe().loc['count']<liquidez_desejada*len(dados.index):
        print(f'Deletando {a} da base de cotacoes')
        dados.drop(columns = [a], inplace = True)
dados
# Out:
# Checando liquidez da ALPA4.SA
# Checando liquidez da ALUP11.SA
# Checando liquidez da ABEV3.SA
# Checando liquidez da BTOW3.SA
# Checando liquidez da BBSE3.SA
# Checando liquidez da BBDC3.SA
# Checando liquidez da BBDC4.SA
# Checando liquidez da BBAS3.SA
# Checando liquidez da BRSR6.SA
# Checando liquidez da SANB11.SA
# Checando liquidez da B3SA3.SA
# Checando liquidez da BRML3.SA
# Checando liquidez da BRAP4.SA
# Checando liquidez da BRKM5.SA
# Checando liquidez da BRFS3.SA
# Checando liquidez da CCRO3.SA
# Checando liquidez da ELET3.SA
# Checando liquidez da ELET6.SA
# Checando liquidez da CESP6.SA
# Checando liquidez da CMIG3.SA
# Checando liquidez da CMIG4.SA
# Checando liquidez da CGAS5.SA
# Checando liquidez da HGTX3.SA
# Checando liquidez da CPLE6.SA
# Checando liquidez da SBSP3.SA
# Checando liquidez da CSMG3.SA
# Checando liquidez da CSNA3.SA
# Checando liquidez da CIEL3.SA
# Checando liquidez da CSAN3.SA
# Checando liquidez da CPFE3.SA
# Checando liquidez da TRPL4.SA
# Checando liquidez da CVCB3.SA
# Checando liquidez da CYRE3.SA
# Checando liquidez da DTEX3.SA
# Checando liquidez da ECOR3.SA
# Checando liquidez da ENBR3.SA
# Checando liquidez da EMBR3.SA
# Checando liquidez da EQTL3.SA
# Checando liquidez da EZTC3.SA
# Checando liquidez da GGBR4.SA
# Checando liquidez da GOLL4.SA
# Checando liquidez da GRND3.SA
# Checando liquidez da HYPE3.SA
# Checando liquidez da IGTA3.SA
# Checando liquidez da MYPK3.SA
# Checando liquidez da ITUB3.SA
# Checando liquidez da ITUB4.SA
# Checando liquidez da ITSA4.SA
# Checando liquidez da JBSS3.SA
# Checando liquidez da KLBN11.SA
# Checando liquidez da LIGT3.SA
# Checando liquidez da RENT3.SA
# Checando liquidez da LAME3.SA
# Checando liquidez da LAME4.SA
# Checando liquidez da LREN3.SA
# Checando liquidez da MDIA3.SA
# Checando liquidez da MGLU3.SA
# Checando liquidez da LEVE3.SA
# Checando liquidez da POMO4.SA
# Checando liquidez da MRFG3.SA
# Checando liquidez da GOAU4.SA
# Checando liquidez da BEEF3.SA
# Checando liquidez da MRVE3.SA
# Checando liquidez da MULT3.SA
# Checando liquidez da ODPV3.SA
# Checando liquidez da OIBR3.SA
# Checando liquidez da OIBR4.SA
# Checando liquidez da PDGR3.SA
# Checando liquidez da PETR3.SA
# Checando liquidez da PETR4.SA
# Checando liquidez da PSSA3.SA
# Checando liquidez da QUAL3.SA
# Checando liquidez da RADL3.SA
# Checando liquidez da SMTO3.SA
# Checando liquidez da SMLS3.SA
# Deletando SMLS3.SA da base de cotacoes
# Checando liquidez da TOTS3.SA
# Checando liquidez da TAEE11.SA
# Checando liquidez da UGPA3.SA
# Checando liquidez da USIM5.SA
# Checando liquidez da VALE3.SA
# Checando liquidez da VLID3.SA
# Checando liquidez da WEGE3.SA
# Checando liquidez da ABCB4.SA
# Checando liquidez da SEER3.SA
# Checando liquidez da FESA4.SA
# Checando liquidez da FESA3.SA
# Deletando FESA3.SA da base de cotacoes
# Checando liquidez da ITSA3.SA
# Checando liquidez da FLRY3.SA
# Checando liquidez da TUPY3.SA
# Checando liquidez da KLBN4.SA
# Checando liquidez da SANB4.SA
# Checando liquidez da RAPT4.SA
# Checando liquidez da ARZZ3.SA
# Checando liquidez da SAPR4.SA
# Checando liquidez da EGIE3.SA
# Checando liquidez da CARD3.SA
# C:\Users\perdi\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Checando liquidez da ANIM3.SA
# Checando liquidez da BRPR3.SA
# Checando liquidez da MOVI3.SA
# Checando liquidez da RAIL3.SA
# Checando liquidez da AZUL4.SA
# Checando liquidez da UNIP6.SA
# Checando liquidez da WIZS3.SA
# Checando liquidez da TEND3.SA
# Checando liquidez da PTBL3.SA
# Checando liquidez da ENGI11.SA
# Checando liquidez da GUAR3.SA
# Checando liquidez da SLCE3.SA
# Checando liquidez da SULA11.SA
# Checando liquidez da CRFB3.SA
# Checando liquidez da LINX3.SA
# Deletando LINX3.SA da base de cotacoes
# Checando liquidez da PRIO3.SA
# Checando liquidez da IRBR3.SA
# Checando liquidez da AMAR3.SA
# Checando liquidez da BPAC11.SA
# Checando liquidez da ENEV3.SA
# Checando liquidez da CAML3.SA
# Checando liquidez da VULC3.SA
# Checando liquidez da EVEN3.SA
# Checando liquidez da GGBR3.SA
# Checando liquidez da FRAS3.SA
# Checando liquidez da SUZB3.SA
# Checando liquidez da SAPR11.SA
# Checando liquidez da LCAM3.SA
# Checando liquidez da BRDT3.SA
# Checando liquidez da BKBR3.SA
# Checando liquidez da TGMA3.SA
# Checando liquidez da HBOR3.SA
# Checando liquidez da ETER3.SA
# Checando liquidez da DIRR3.SA
# Checando liquidez da MEAL3.SA
# Checando liquidez da UNIP3.SA
# Checando liquidez da HAPV3.SA
# Checando liquidez da PARD3.SA
# Checando liquidez da VIVT3.SA
# Checando liquidez da SHOW3.SA
# Checando liquidez da BBRK3.SA
# Checando liquidez da PMAM3.SA
# Checando liquidez da VIVR3.SA
# Checando liquidez da MILS3.SA
# Checando liquidez da LPSB3.SA
# Checando liquidez da CPLE3.SA
# Checando liquidez da BRAP3.SA
# Checando liquidez da POSI3.SA
# Checando liquidez da ROMI3.SA
# Checando liquidez da KEPL3.SA
# Checando liquidez da SANB3.SA
# Checando liquidez da LOGN3.SA
# Checando liquidez da AALR3.SA
# Checando liquidez da FHER3.SA
# Checando liquidez da USIM3.SA
# Checando liquidez da SLED4.SA
# Checando liquidez da PFRM3.SA
# Checando liquidez da AGRO3.SA
# Checando liquidez da TPIS3.SA
# Checando liquidez da GNDI3.SA
# Checando liquidez da BPAN4.SA
# Checando liquidez da STBP3.SA
# Checando liquidez da TCSA3.SA
# Checando liquidez da RSID3.SA
# Checando liquidez da SGPS3.SA
# Checando liquidez da OMGE3.SA
# Checando liquidez da CRPG5.SA
# Checando liquidez da GOAU3.SA
# Checando liquidez da LUPA3.SA
# Checando liquidez da ATOM3.SA
# Checando liquidez da JHSF3.SA
# Checando liquidez da VVAR3.SA
# Checando liquidez da TRIS3.SA
# Checando liquidez da CGRA4.SA
# Checando liquidez da SHUL4.SA
# Checando liquidez da POMO3.SA
# Checando liquidez da SAPR3.SA
# Checando liquidez da BEES3.SA
# Checando liquidez da TAEE4.SA
# Checando liquidez da COCE5.SA
# Checando liquidez da TAEE3.SA
# Checando liquidez da KLBN3.SA
# Checando liquidez da BRSR3.SA
# Checando liquidez da ENGI3.SA
# Checando liquidez da AZEV4.SA
# Checando liquidez da RCSL4.SA
# Checando liquidez da TECN3.SA
# Checando liquidez da OFSA3.SA
# Checando liquidez da PINE4.SA
# Checando liquidez da BRKM3.SA
# Checando liquidez da BMEB4.SA
# Checando liquidez da GSHP3.SA
# Deletando GSHP3.SA da base de cotacoes
# Checando liquidez da TESA3.SA
# Checando liquidez da SCAR3.SA
# Checando liquidez da ALPA3.SA
# Checando liquidez da ENGI4.SA
# Checando liquidez da GEPA4.SA
# Deletando GEPA4.SA da base de cotacoes
# Checando liquidez da TRPL3.SA
# Checando liquidez da UCAS3.SA
# Checando liquidez da BOBR4.SA
# Checando liquidez da JBDU4.SA
# Checando liquidez da LLIS3.SA
# Checando liquidez da ALUP4.SA
# Checando liquidez da TELB4.SA
# Checando liquidez da EUCA4.SA
# Checando liquidez da RAPT3.SA
# Checando liquidez da RPMG3.SA
# Checando liquidez da BEES4.SA
# Checando liquidez da WHRL3.SA
# Checando liquidez da RANI3.SA
# Checando liquidez da CTNM4.SA
# Checando liquidez da WHRL4.SA
# Checando liquidez da SLED3.SA
# Checando liquidez da PTNT4.SA
# Checando liquidez da NEOE3.SA
# Checando liquidez da BIDI11.SA
# Checando liquidez da IGBR3.SA
# Checando liquidez da MTSA4.SA
# Checando liquidez da EALT4.SA
# Checando liquidez da BSEV3.SA
# Deletando BSEV3.SA da base de cotacoes
# Checando liquidez da BAZA3.SA
# Checando liquidez da OSXB3.SA
# Deletando OSXB3.SA da base de cotacoes
# Checando liquidez da SULA4.SA
# Checando liquidez da ALUP3.SA
# Checando liquidez da HAGA4.SA
# Checando liquidez da SULA3.SA
# Checando liquidez da CTSA3.SA
# Checando liquidez da RNEW11.SA
# Checando liquidez da BIOM3.SA
# Checando liquidez da JBDU3.SA
# Checando liquidez da RDNI3.SA
# Checando liquidez da MMXM3.SA
# Deletando MMXM3.SA da base de cotacoes
# Checando liquidez da CGRA3.SA
# Deletando CGRA3.SA da base de cotacoes
# Checando liquidez da UNIP5.SA
# Deletando UNIP5.SA da base de cotacoes
# Checando liquidez da AFLT3.SA
# Date
# 2020-06-24      2.65      1.48  19.056448   8.670336     10.30  27.061110
# 2020-06-25      2.64      1.52  18.718988   8.909370     10.01  26.204994
# 2020-06-26      2.55      1.45  19.721437   8.611515      9.82  25.929464
# 2020-06-29      2.56      1.50  22.828033   9.123376     10.44  26.569090
# 2020-06-30      2.55      1.49  24.058762   8.883088     10.31  25.742496
# ...              ...       ...        ...        ...       ...        ...
# 2021-07-07      5.44      4.55  19.360001  37.330002     13.73  20.850000
# 2021-07-08      5.12      4.20  19.370001  37.070000     13.59  20.990000
# 2021-07-12      5.05      4.21  19.260000  37.060001     13.49  20.510000
# 2021-07-13      4.84      4.10  19.490000  36.590000     13.42  20.480000
# 2021-07-14      4.68      4.03  19.250000  36.639999     13.45  20.760000
#
#             BMGB4.SA  CAMB3.SA     ^BVSP
# Date
# 2020-06-24  5.218503      4.95   94377.0
# 2020-06-25  5.179704      4.79   95983.0
# 2020-06-26  4.927509      4.45   93834.0
# 2020-06-29  5.208803      4.25   95735.0
# 2020-06-30  5.237903      4.20   95056.0
# ...              ...       ...       ...
# 2021-07-07  4.830000      5.72  127019.0
# 2021-07-08  4.700000      5.51  125428.0
# 2021-07-12  4.840000      5.57  127594.0
# 2021-07-13  4.890000      5.57  128168.0
# 2021-07-14  4.830000      5.65  128407.0
#
# [260 rows x 241 columns]

# %%
for a in dados.columns:
    print(f'Checando liquidez da {a}')
    if dados.describe()[a].loc['count']<liquidez_desejada*len(dados.index):
        print(f'Liquidez ainda está fora do padrão')
        print(dados.describe()[a].loc['count'])
    else:
        print(f'Liquidez ok')
# Out:
# Checando liquidez da ALPA4.SA
# Liquidez ok
# Checando liquidez da ALUP11.SA
# Liquidez ok
# Checando liquidez da ABEV3.SA
# Liquidez ok
# Checando liquidez da BTOW3.SA
# Liquidez ok
# Checando liquidez da BBSE3.SA
# Liquidez ok
# Checando liquidez da BBDC3.SA
# Liquidez ok
# Checando liquidez da BBDC4.SA
# Liquidez ok
# Checando liquidez da BBAS3.SA
# Liquidez ok
# Checando liquidez da BRSR6.SA
# Liquidez ok
# Checando liquidez da SANB11.SA
# Liquidez ok
# Checando liquidez da B3SA3.SA
# Liquidez ok
# Checando liquidez da BRML3.SA
# Liquidez ok
# Checando liquidez da BRAP4.SA
# Liquidez ok
# Checando liquidez da BRKM5.SA
# Liquidez ok
# Checando liquidez da BRFS3.SA
# Liquidez ok
# Checando liquidez da CCRO3.SA
# Liquidez ok
# Checando liquidez da ELET3.SA
# Liquidez ok
# Checando liquidez da ELET6.SA
# Liquidez ok
# Checando liquidez da CESP6.SA
# Liquidez ok
# Checando liquidez da CMIG3.SA
# Liquidez ok
# Checando liquidez da CMIG4.SA
# Liquidez ok
# Checando liquidez da CGAS5.SA
# Liquidez ok
# Checando liquidez da HGTX3.SA
# Liquidez ok
# Checando liquidez da CPLE6.SA
# Liquidez ok
# Checando liquidez da SBSP3.SA
# Liquidez ok
# Checando liquidez da CSMG3.SA
# Liquidez ok
# Checando liquidez da CSNA3.SA
# Liquidez ok
# Checando liquidez da CIEL3.SA
# Liquidez ok
# Checando liquidez da CSAN3.SA
# Liquidez ok
# Checando liquidez da CPFE3.SA
# Liquidez ok
# Checando liquidez da TRPL4.SA
# Liquidez ok
# Checando liquidez da CVCB3.SA
# Liquidez ok
# Checando liquidez da CYRE3.SA
# Liquidez ok
# Checando liquidez da DTEX3.SA
# Liquidez ok
# Checando liquidez da ECOR3.SA
# Liquidez ok
# Checando liquidez da ENBR3.SA
# Liquidez ok
# Checando liquidez da EMBR3.SA
# Liquidez ok
# Checando liquidez da EQTL3.SA
# Liquidez ok
# Checando liquidez da EZTC3.SA
# Liquidez ok
# Checando liquidez da GGBR4.SA
# Liquidez ok
# Checando liquidez da GOLL4.SA
# Liquidez ok
# Checando liquidez da GRND3.SA
# Liquidez ok
# Checando liquidez da HYPE3.SA
# Liquidez ok
# Checando liquidez da IGTA3.SA
# Liquidez ok
# Checando liquidez da MYPK3.SA
# Liquidez ok
# Checando liquidez da ITUB3.SA
# Liquidez ok
# Checando liquidez da ITUB4.SA
# Liquidez ok
# Checando liquidez da ITSA4.SA
# Liquidez ok
# Checando liquidez da JBSS3.SA
# Liquidez ok
# Checando liquidez da KLBN11.SA
# Liquidez ok
# Checando liquidez da LIGT3.SA
# Liquidez ok
# Checando liquidez da RENT3.SA
# Liquidez ok
# Checando liquidez da LAME3.SA
# Liquidez ok
# Checando liquidez da LAME4.SA
# Liquidez ok
# Checando liquidez da LREN3.SA
# Liquidez ok
# Checando liquidez da MDIA3.SA
# Liquidez ok
# Checando liquidez da MGLU3.SA
# Liquidez ok
# Checando liquidez da LEVE3.SA
# Liquidez ok
# Checando liquidez da POMO4.SA
# Liquidez ok
# Checando liquidez da MRFG3.SA
# Liquidez ok
# Checando liquidez da GOAU4.SA
# Liquidez ok
# Checando liquidez da BEEF3.SA
# Liquidez ok
# Checando liquidez da MRVE3.SA
# Liquidez ok
# Checando liquidez da MULT3.SA
# Liquidez ok
# Checando liquidez da ODPV3.SA
# Liquidez ok
# Checando liquidez da OIBR3.SA
# Liquidez ok
# Checando liquidez da OIBR4.SA
# Liquidez ok
# Checando liquidez da PDGR3.SA
# Liquidez ok
# Checando liquidez da PETR3.SA
# Liquidez ok
# Checando liquidez da PETR4.SA
# Liquidez ok
# Checando liquidez da PSSA3.SA
# Liquidez ok
# Checando liquidez da QUAL3.SA
# Liquidez ok
# Checando liquidez da RADL3.SA
# Liquidez ok
# Checando liquidez da SMTO3.SA
# Liquidez ok
# Checando liquidez da TOTS3.SA
# Liquidez ok
# Checando liquidez da TAEE11.SA
# Liquidez ok
# Checando liquidez da UGPA3.SA
# Liquidez ok
# Checando liquidez da USIM5.SA
# Liquidez ok
# Checando liquidez da VALE3.SA
# Liquidez ok
# Checando liquidez da VLID3.SA
# Liquidez ok
# Checando liquidez da WEGE3.SA
# Liquidez ok
# Checando liquidez da ABCB4.SA
# Liquidez ok
# Checando liquidez da SEER3.SA
# Liquidez ok
# Checando liquidez da FESA4.SA
# Liquidez ok
# Checando liquidez da ITSA3.SA
# Liquidez ok
# Checando liquidez da FLRY3.SA
# Liquidez ok
# Checando liquidez da TUPY3.SA
# Liquidez ok
# Checando liquidez da KLBN4.SA
# Liquidez ok
# Checando liquidez da SANB4.SA
# Liquidez ok
# Checando liquidez da RAPT4.SA
# Liquidez ok
# Checando liquidez da ARZZ3.SA
# Liquidez ok
# Checando liquidez da SAPR4.SA
# Liquidez ok
# Checando liquidez da EGIE3.SA
# Liquidez ok
# Checando liquidez da CARD3.SA
# Liquidez ok
# Checando liquidez da ANIM3.SA
# Liquidez ok
# Checando liquidez da BRPR3.SA
# Liquidez ok
# Checando liquidez da MOVI3.SA
# Liquidez ok
# Checando liquidez da RAIL3.SA
# Liquidez ok
# Checando liquidez da AZUL4.SA
# Liquidez ok
# Checando liquidez da UNIP6.SA
# Liquidez ok
# Checando liquidez da WIZS3.SA
# Liquidez ok
# Checando liquidez da TEND3.SA
# Liquidez ok
# Checando liquidez da PTBL3.SA
# Liquidez ok
# Checando liquidez da ENGI11.SA
# Liquidez ok
# Checando liquidez da GUAR3.SA
# Liquidez ok
# Checando liquidez da SLCE3.SA
# Liquidez ok
# Checando liquidez da SULA11.SA
# Liquidez ok
# Checando liquidez da CRFB3.SA
# Liquidez ok
# Checando liquidez da PRIO3.SA
# Liquidez ok
# Checando liquidez da IRBR3.SA
# Liquidez ok
# Checando liquidez da AMAR3.SA
# Liquidez ok
# Checando liquidez da BPAC11.SA
# Liquidez ok
# Checando liquidez da ENEV3.SA
# Liquidez ok
# Checando liquidez da CAML3.SA
# Liquidez ok
# Checando liquidez da VULC3.SA
# Liquidez ok
# Checando liquidez da EVEN3.SA
# Liquidez ok
# Checando liquidez da GGBR3.SA
# Liquidez ok
# Checando liquidez da FRAS3.SA
# Liquidez ok
# Checando liquidez da SUZB3.SA
# Liquidez ok
# Checando liquidez da SAPR11.SA
# Liquidez ok
# Checando liquidez da LCAM3.SA
# Liquidez ok
# Checando liquidez da BRDT3.SA
# Liquidez ok
# Checando liquidez da BKBR3.SA
# Liquidez ok
# Checando liquidez da TGMA3.SA
# Liquidez ok
# Checando liquidez da HBOR3.SA
# Liquidez ok
# Checando liquidez da ETER3.SA
# Liquidez ok
# Checando liquidez da DIRR3.SA
# Liquidez ok
# Checando liquidez da MEAL3.SA
# Liquidez ok
# Checando liquidez da UNIP3.SA
# Liquidez ok
# Checando liquidez da HAPV3.SA
# Liquidez ok
# Checando liquidez da PARD3.SA
# Liquidez ok
# Checando liquidez da VIVT3.SA
# Liquidez ok
# Checando liquidez da SHOW3.SA
# Liquidez ok
# Checando liquidez da BBRK3.SA
# Liquidez ok
# Checando liquidez da PMAM3.SA
# Liquidez ok
# Checando liquidez da VIVR3.SA
# Liquidez ok
# Checando liquidez da MILS3.SA
# Liquidez ok
# Checando liquidez da LPSB3.SA
# Liquidez ok
# Checando liquidez da CPLE3.SA
# Liquidez ok
# Checando liquidez da BRAP3.SA
# Liquidez ok
# Checando liquidez da POSI3.SA
# Liquidez ok
# Checando liquidez da ROMI3.SA
# Liquidez ok
# Checando liquidez da KEPL3.SA
# Liquidez ok
# Checando liquidez da SANB3.SA
# Liquidez ok
# Checando liquidez da LOGN3.SA
# Liquidez ok
# Checando liquidez da AALR3.SA
# Liquidez ok
# Checando liquidez da FHER3.SA
# Liquidez ok
# Checando liquidez da USIM3.SA
# Liquidez ok
# Checando liquidez da SLED4.SA
# Liquidez ok
# Checando liquidez da PFRM3.SA
# Liquidez ok
# Checando liquidez da AGRO3.SA
# Liquidez ok
# Checando liquidez da TPIS3.SA
# Liquidez ok
# Checando liquidez da GNDI3.SA
# Liquidez ok
# Checando liquidez da BPAN4.SA
# Liquidez ok
# Checando liquidez da STBP3.SA
# Liquidez ok
# Checando liquidez da TCSA3.SA
# Liquidez ok
# Checando liquidez da RSID3.SA
# Liquidez ok
# Checando liquidez da SGPS3.SA
# Liquidez ok
# Checando liquidez da OMGE3.SA
# Liquidez ok
# Checando liquidez da CRPG5.SA
# Liquidez ok
# Checando liquidez da GOAU3.SA
# Liquidez ok
# Checando liquidez da LUPA3.SA
# Liquidez ok
# Checando liquidez da ATOM3.SA
# Liquidez ok
# Checando liquidez da JHSF3.SA
# Liquidez ok
# Checando liquidez da VVAR3.SA
# Liquidez ok
# Checando liquidez da TRIS3.SA
# Liquidez ok
# Checando liquidez da CGRA4.SA
# Liquidez ok
# Checando liquidez da SHUL4.SA
# Liquidez ok
# Checando liquidez da POMO3.SA
# Liquidez ok
# Checando liquidez da SAPR3.SA
# Liquidez ok
# Checando liquidez da BEES3.SA
# Liquidez ok
# Checando liquidez da TAEE4.SA
# Liquidez ok
# Checando liquidez da COCE5.SA
# Liquidez ok
# Checando liquidez da TAEE3.SA
# Liquidez ok
# Checando liquidez da KLBN3.SA
# Liquidez ok
# Checando liquidez da BRSR3.SA
# Liquidez ok
# Checando liquidez da ENGI3.SA
# Liquidez ok
# Checando liquidez da AZEV4.SA
# Liquidez ok
# Checando liquidez da RCSL4.SA
# Liquidez ok
# Checando liquidez da TECN3.SA
# Liquidez ok
# Checando liquidez da OFSA3.SA
# Liquidez ok
# Checando liquidez da PINE4.SA
# Liquidez ok
# Checando liquidez da BRKM3.SA
# Liquidez ok
# Checando liquidez da BMEB4.SA
# Liquidez ok
# Checando liquidez da TESA3.SA
# Liquidez ok
# Checando liquidez da SCAR3.SA
# Liquidez ok
# Checando liquidez da ALPA3.SA
# Liquidez ok
# Checando liquidez da ENGI4.SA
# Liquidez ok
# Checando liquidez da TRPL3.SA
# Liquidez ok
# Checando liquidez da UCAS3.SA
# Liquidez ok
# Checando liquidez da BOBR4.SA
# Liquidez ok
# Checando liquidez da JBDU4.SA
# Liquidez ok
# Checando liquidez da LLIS3.SA
# Liquidez ok
# Checando liquidez da ALUP4.SA
# Liquidez ok
# Checando liquidez da TELB4.SA
# Liquidez ok
# Checando liquidez da EUCA4.SA
# Liquidez ok
# Checando liquidez da RAPT3.SA
# Liquidez ok
# Checando liquidez da RPMG3.SA
# Liquidez ok
# Checando liquidez da BEES4.SA
# Liquidez ok
# Checando liquidez da WHRL3.SA
# Liquidez ok
# Checando liquidez da RANI3.SA
# Liquidez ok
# Checando liquidez da CTNM4.SA
# Liquidez ok
# Checando liquidez da WHRL4.SA
# Liquidez ok
# Checando liquidez da SLED3.SA
# Liquidez ok
# Checando liquidez da PTNT4.SA
# Liquidez ok
# Checando liquidez da NEOE3.SA
# Liquidez ok
# Checando liquidez da BIDI11.SA
# Liquidez ok
# Checando liquidez da IGBR3.SA
# Liquidez ok
# Checando liquidez da MTSA4.SA
# Liquidez ok
# Checando liquidez da EALT4.SA
# Liquidez ok
# Checando liquidez da BAZA3.SA
# Liquidez ok
# Checando liquidez da SULA4.SA
# Liquidez ok
# Checando liquidez da ALUP3.SA
# Liquidez ok
# Checando liquidez da HAGA4.SA
# Liquidez ok
# Checando liquidez da SULA3.SA
# Liquidez ok
# Checando liquidez da CTSA3.SA
# Liquidez ok
# Checando liquidez da RNEW11.SA
# Liquidez ok
# Checando liquidez da BIOM3.SA
# Liquidez ok
# Checando liquidez da JBDU3.SA
# Liquidez ok
# Checando liquidez da RDNI3.SA
# Liquidez ok
# Checando liquidez da PNVL3.SA
# Liquidez ok
# Checando liquidez da RNEW4.SA
# Liquidez ok
# Checando liquidez da RCSL3.SA
# Liquidez ok
# Checando liquidez da RNEW3.SA
# Liquidez ok
# Checando liquidez da CCPR3.SA
# Liquidez ok
# Checando liquidez da FRTA3.SA
# Liquidez ok
# Checando liquidez da CLSC4.SA
# Liquidez ok
# Checando liquidez da CESP3.SA
# Liquidez ok
# Checando liquidez da EMAE4.SA
# Liquidez ok
# Checando liquidez da PSVM11.SA
# Liquidez ok
# Checando liquidez da MWET4.SA
# Liquidez ok
# Checando liquidez da VIVA3.SA
# Liquidez ok
# Checando liquidez da TCNO3.SA
# Liquidez ok
# Checando liquidez da TCNO4.SA
# Liquidez ok
# Checando liquidez da PNVL4.SA
# Liquidez ok
# Checando liquidez da PCAR3.SA
# Liquidez ok
# Checando liquidez da CEAB3.SA
# Liquidez ok
# Checando liquidez da EUCA3.SA
# Liquidez ok
# Checando liquidez da BMGB4.SA
# Liquidez ok
# Checando liquidez da CAMB3.SA
# Liquidez ok
# Checando liquidez da ^BVSP
# Liquidez ok

# %%
import copy

acoes = list(dados.columns)
acoes_sem_bvsp = copy.deepcopy(acoes)
acoes_sem_bvsp.remove('^BVSP')
dados
# Out:
#              ALPA4.SA  ALUP11.SA   ABEV3.SA    BTOW3.SA   BBSE3.SA   BBDC3.SA  \
# Date
# 2020-06-24  29.690001  23.057539  13.264391  105.911911  27.054909  16.617493
# 2020-06-25  30.120001  23.348061  13.749201  104.895348  27.655704  16.971972
# 2020-06-26  28.940001  23.173748  13.526188  102.752594  26.559013  16.496445
# 2020-06-29  29.379999  23.532055  13.826770  105.792313  26.940470  16.911457
# 2020-06-30  29.280001  23.212482  13.710416  106.689285  26.005898  16.392698
# ...               ...        ...        ...         ...        ...        ...
# 2021-07-07  53.400002  26.309999  17.770000   66.800003  22.850000  21.059999
# 2021-07-08  53.040001  26.030001  17.360001   65.919998  22.600000  20.760000
# ## Retorno médio

# %%
retornos_diarios_med = retornos_diarios.mean()
retornos_diarios_med = retornos_diarios_med.rename('Retornos diários médios')
retornos_diarios_med
# Out:
# ALPA4.SA     1.002489
# ALUP11.SA    1.000635
# ABEV3.SA     1.001385
# BTOW3.SA     0.998680
# BBSE3.SA     0.999514
#                ...
# CEAB3.SA     1.001503
# EUCA3.SA     0.999298
# BMGB4.SA     0.999984
# CAMB3.SA     1.000913
# ^BVSP        1.001278
# Name: Retornos diários médios, Length: 241, dtype: float64

# %% [markdown]
# ## Retornos mínimos e máximos

# %%
ret_min = pd.Series(dtype = float)
ret_max = pd.Series(dtype = float)
ret_min.reindex_like(retornos_diarios_med)
ret_max.reindex_like(retornos_diarios_med)
for a in acoes:
    ret_min[a] = retornos_diarios[a].min()-1
    ret_max[a] = retornos_diarios[a].max()-1
ret_min = ret_min.rename("Retorno Mínimo")
ret_max = ret_max.rename("Retorno Máximo")

# %% [markdown]
# ## Retorno acumulado

# %%
ret_acum=dados.iloc[-1]/dados.iloc[0]
ret_acum=ret_acum.rename("Retorno líquido acumulado")

# %% [markdown]
# ## Dataframe de Retorno

# %%
retorno = pd.DataFrame()
retorno = retorno.append(retornos_diarios_med)
retorno = retorno.append(ret_min)
retorno = retorno.append(ret_max)
retorno = retorno.append(ret_acum)
del retorno['^BVSP']
retorno
# Out:
#                            AALR3.SA  ABCB4.SA  ABEV3.SA  AGRO3.SA  ALPA3.SA  \
# Retornos diários médios    1.000790  1.000651  1.001385  1.001857  1.002744
# Retorno Mínimo            -0.076067 -0.053784 -0.057239 -0.051016 -0.113364
# Retorno Máximo             0.130238  0.047826  0.088829  0.064898  0.095630
# Retorno líquido acumulado  1.090204  1.137603  1.350232  1.529259  1.893004
#
#                            ALPA4.SA  ALUP11.SA  ALUP3.SA  ALUP4.SA  AMAR3.SA  \
# Retornos diários médios    1.002489   1.000635  0.999852  1.001190  1.000810
# Retorno Mínimo            -0.093207  -0.038369 -0.049847 -0.034216 -0.075924
# Retorno Máximo             0.137714   0.047059  0.051282  0.044678  0.147330
# Retorno líquido acumulado  1.767935   1.153636  0.932279  1.318325  1.068293
#
#                            ...  VIVA3.SA  VIVR3.SA  VIVT3.SA  VLID3.SA  \
# Retornos diários médios    ...  1.001988  1.005895  0.999836  1.000231
# Retorno Mínimo             ... -0.070363 -0.510703 -0.046767 -0.084746
# Retorno Máximo             ...  0.098861  0.665535  0.056391  0.105806
# Retorno líquido acumulado  ...  1.540339  2.041811  0.931616  0.935706
#
#                            VULC3.SA  VVAR3.SA  WEGE3.SA  WHRL3.SA  WHRL4.SA  \
# Retornos diários médios    1.003206  1.000496  1.001972  1.000801  1.001185
# Retorno Mínimo            -0.108781 -0.075714 -0.077278 -0.043243 -0.047619
# Retorno Máximo             0.069767  0.081528  0.138945  0.047619  0.058278
# Retorno líquido acumulado  2.132000  1.019204  1.534688  1.199804  1.320130
#
#                            WIZS3.SA
# Retornos diários médios    1.002513
# Retorno Mínimo            -0.156888
# Retorno Máximo             0.158908
# Retorno líquido acumulado  1.632933
#
# [4 rows x 240 columns]

# %% [markdown]
# # Métricas de Risco

# %% [markdown]
# ## Calculando a semivariância

# %%
def f_semivariancia (retornos_diarios, media):
    tamanho=len(retornos_diarios)
    somatorio = 0
    #print('Média: ' + str(media))                                   // para debug
    #print('Retorno no dia 1: ' + str(retornos_diarios.iloc[1]))     // para debug
    t = 0
    while t in range(tamanho):
        dif = (retornos_diarios.iloc[t] - media)
        #print('Dif = ' + str(retornos_diarios.iloc[t] - media))    // para debug
        if dif < 0:
            somatorio += dif ** 2
        t += 1
    med = somatorio / tamanho
    semivariancia = med ** (0.5)
    return (semivariancia)

# %%
semivariancia = []
for a in acoes:
    semivariancia.append(f_semivariancia(retornos_diarios[a],retornos_diarios_med.loc[a]))
semivariancia
semivariancia = pd.Series(semivariancia)
semivariancia.index = acoes
semivariancia = semivariancia.rename('Semivariância')
semivariancia
# Out:
# ALPA4.SA     0.016098
# ALUP11.SA    0.008658
# ABEV3.SA     0.014434
# BTOW3.SA     0.020070
# BBSE3.SA     0.011228
#                ...
# CEAB3.SA     0.020413
# EUCA3.SA     0.015440
# BMGB4.SA     0.015334
# CAMB3.SA     0.018723
# ^BVSP        0.009844
# Name: Semivariância, Length: 241, dtype: float64

# %% [markdown]
# ## Calculando desvio padrão

# %%
desvio_padrao = retornos_diarios.std()
desvio_padrao = desvio_padrao.rename('Desvio Padrão')
desvio_padrao
# Out:
# ALPA4.SA     0.024109
# ALUP11.SA    0.012940
# ABEV3.SA     0.021308
# BTOW3.SA     0.030878
# BBSE3.SA     0.015742
#                ...
# CEAB3.SA     0.030935
# EUCA3.SA     0.025700
# BMGB4.SA     0.023927
# CAMB3.SA     0.028567
# ^BVSP        0.013336
# Name: Desvio Padrão, Length: 241, dtype: float64

# %% [markdown]
# ## Calculando beta de mercado

# %%
cov = retornos_diarios.cov()
cov
# Out:
#            ALPA4.SA  ALUP11.SA  ABEV3.SA  BTOW3.SA  BBSE3.SA  BBDC3.SA  \
# ALPA4.SA   0.000581   0.000071  0.000084  0.000217  0.000125  0.000077
# ALUP11.SA  0.000071   0.000167  0.000088  0.000117  0.000082  0.000102
# ABEV3.SA   0.000084   0.000088  0.000454  0.000134  0.000177  0.000272
# BTOW3.SA   0.000217   0.000117  0.000134  0.000953  0.000178  0.000049
# BBSE3.SA   0.000125   0.000082  0.000177  0.000178  0.000248  0.000202
# ...             ...        ...       ...       ...       ...       ...
# CEAB3.SA   0.000200   0.000145  0.000184  0.000262  0.000198  0.000232
# EUCA3.SA  -0.000006   0.000006  0.000052  0.000028  0.000054  0.000073
# BMGB4.SA   0.000102   0.000090  0.000160  0.000118  0.000115  0.000212
# CAMB3.SA   0.000087   0.000030  0.000052  0.000115  0.000061  0.000078
# ^BVSP      0.000113   0.000078  0.000177  0.000138  0.000149  0.000223
#
#            BBDC4.SA  BBAS3.SA  BRSR6.SA  SANB11.SA  ...  VIVA3.SA  TCNO3.SA  \
# ALPA4.SA   0.000067  0.000075  0.000076   0.000067  ...  0.000234  0.000082
# ALUP11.SA  0.000097  0.000096  0.000093   0.000086  ...  0.000084  0.000050
# ABEV3.SA   0.000285  0.000236  0.000189   0.000250  ...  0.000199  0.000107
# BTOW3.SA   0.000032  0.000082  0.000066   0.000059  ...  0.000203 -0.000007
# BBSE3.SA   0.000193  0.000190  0.000161   0.000188  ...  0.000192  0.000087
# ...             ...       ...       ...        ...  ...       ...       ...
# CEAB3.SA   0.000214  0.000184  0.000153   0.000163  ...  0.000351  0.000186
# EUCA3.SA   0.000071  0.000065  0.000030   0.000062  ...  0.000051  0.000032
# BMGB4.SA   0.000219  0.000218  0.000218   0.000205  ...  0.000271  0.000049
# CAMB3.SA   0.000079  0.000080  0.000122   0.000067  ...  0.000101  0.000017
# ^BVSP      0.000221  0.000218  0.000163   0.000208  ...  0.000175  0.000096
#
#            TCNO4.SA  PNVL4.SA  PCAR3.SA  CEAB3.SA  EUCA3.SA  BMGB4.SA  \
# ALPA4.SA   0.000040  0.000061  0.000163  0.000200 -0.000006  0.000102
# ALUP11.SA  0.000030  0.000055  0.000061  0.000145  0.000006  0.000090
# ABEV3.SA   0.000141  0.000021  0.000084  0.000184  0.000052  0.000160
# BTOW3.SA   0.000028  0.000098  0.000137  0.000262  0.000028  0.000118
# BBSE3.SA   0.000077  0.000028  0.000027  0.000198  0.000054  0.000115
# ...             ...       ...       ...       ...       ...       ...
# CEAB3.SA   0.000138  0.000175 -0.000044  0.000957  0.000072  0.000231
# EUCA3.SA   0.000147  0.000036  0.000008  0.000072  0.000660  0.000057
# BMGB4.SA   0.000069  0.000150  0.000031  0.000231  0.000057  0.000573
# CAMB3.SA   0.000025  0.000088 -0.000223  0.000084 -0.000044  0.000129
# ^BVSP      0.000065  0.000084  0.000123  0.000176  0.000033  0.000152
#
#            CAMB3.SA     ^BVSP
# ALPA4.SA   0.000087  0.000113
# ALUP11.SA  0.000030  0.000078
# ABEV3.SA   0.000052  0.000177
# BTOW3.SA   0.000115  0.000138
# BBSE3.SA   0.000061  0.000149
# ...             ...       ...
# CEAB3.SA   0.000084  0.000176
# EUCA3.SA  -0.000044  0.000033
# BMGB4.SA   0.000129  0.000152
# CAMB3.SA   0.000816  0.000088
# ^BVSP      0.000088  0.000178
#
# [241 rows x 241 columns]

# %%
beta = []
for a in acoes:
    beta.append(cov.loc[a, '^BVSP']/retornos_diarios['^BVSP'].var())
beta = pd.Series(beta)
beta.index = acoes
beta = beta.rename('Beta de mercado')
beta
# Out:
# ALPA4.SA     0.632591
# ALUP11.SA    0.437222
# ABEV3.SA     0.994627
# BTOW3.SA     0.776300
# BBSE3.SA     0.835002
#                ...
# CEAB3.SA     0.991273
# EUCA3.SA     0.185694
# BMGB4.SA     0.857333
# CAMB3.SA     0.495691
# ^BVSP        1.000000
# Name: Beta de mercado, Length: 241, dtype: float64

# %% [markdown]
# ## Calculando Downside Risk

# %%
def f_downside (retornos_diarios_acao, retornos_diarios_bovespa):
    tamanho=len(retornos_diarios)
    t = 0
    dif = (retornos_diarios_acao - retornos_diarios_bovespa)
    while t in range(tamanho):
        if dif.iloc[t] > 0:
            dif.iloc[t] = 0
        t += 1
    dif = dif ** 2
    media = dif.mean()
    Downside_Risk = media ** (0.5)
    return (Downside_Risk)

# %%
Downside_Risk = []
for a in acoes:
    Downside_Risk.append(f_downside(retornos_diarios[a],retornos_diarios['^BVSP']))
Downside_Risk = pd.Series(Downside_Risk)
Downside_Risk.index = acoes
Downside_Risk = Downside_Risk.rename('Downside Risk')
Downside_Risk
# Out:
# ALPA4.SA     0.014756
# ALUP11.SA    0.009601
# ABEV3.SA     0.010642
# BTOW3.SA     0.020606
# BBSE3.SA     0.009180
#                ...
# CEAB3.SA     0.018352
# EUCA3.SA     0.018346
# BMGB4.SA     0.013855
# CAMB3.SA     0.018587
# ^BVSP        0.000000
# Name: Downside Risk, Length: 241, dtype: float64

# %% [markdown]
# ## Calcular TEV

# %%
TE = retornos_diarios.sub(retornos_diarios['^BVSP'], axis=0)
TEV = TE.std()
TEV.rename("Tracking Error Volatility", inplace = True)
TEV
# Out:
# ALPA4.SA     0.023110
# ALUP11.SA    0.013776
# ABEV3.SA     0.016676
# BTOW3.SA     0.029243
# BBSE3.SA     0.011342
#                ...
# CEAB3.SA     0.027968
# EUCA3.SA     0.027790
# BMGB4.SA     0.021104
# CAMB3.SA     0.028594
# ^BVSP        0.000000
# Name: Tracking Error Volatility, Length: 241, dtype: float64

# %% [markdown]
# ## Calcular Drawdown

# %%
RBA = pd.DataFrame()
serie_unit = []
tamanho_dias = len(retornos_diarios)
a = 0
while a in range(len(acoes)):
    serie_unit.append(1)
    a += 1
serie_unit = pd.Series(serie_unit)
serie_unit.index = acoes
RBA = RBA.reindex_like(retornos_diarios, method = 'backfill')
RBA.iloc[0] = serie_unit
for a in acoes:
    t=1
    while t in range(tamanho_dias):
        RBA[a].iloc[t]=RBA[a].iloc[t-1]*retornos_diarios[a].iloc[t]
        t+=1
RBA
# Out:
#             ALPA4.SA  ALUP11.SA  ABEV3.SA  BTOW3.SA  BBSE3.SA  BBDC3.SA  \
# Date
# 2020-06-24  1.000000   1.000000  1.000000  1.000000  1.000000  1.000000
# 2020-06-25  1.014483   1.012600  1.036550  0.990402  1.022207  1.021332
# 2020-06-26  0.974739   1.005040  1.019737  0.970170  0.981671  0.992716
# 2020-06-29  0.989559   1.020580  1.042398  0.998871  0.995770  1.017690
# 2020-06-30  0.986191   1.006720  1.033626  1.007340  0.961227  0.986472
# ...              ...        ...       ...       ...       ...       ...
# 2021-07-07  1.798585   1.141058  1.339677  0.630713  0.844579  1.267339
# 2021-07-08  1.786460   1.128915  1.308767  0.622404  0.835338  1.249286
# 2021-07-12  1.780397   1.125445  1.331384  0.635434  0.856407  1.275764
# 2021-07-13  1.772651   1.132385  1.341939  0.647236  0.842731  1.279977
# 2021-07-14  1.767935   1.153636  1.350232  0.628352  0.853819  1.296224
#
#             BBDC4.SA  BBAS3.SA  BRSR6.SA  SANB11.SA  ...  VIVA3.SA  TCNO3.SA  \
# Date                                                 ...
# 2020-06-24  1.000000  1.000000  1.000000   1.000000  ...  1.000000  1.000000
# 2020-06-25  1.023981  1.024519  1.008602   1.019411  ...  1.005266  0.996226
# 2020-06-26  0.992326  0.987585  0.979928   0.982322  ...  0.966491  0.962264
# 2020-06-29  1.026858  1.037865  0.998566   1.006932  ...  0.973193  0.966038
# 2020-06-30  0.992806  0.997827  0.971326   0.971230  ...  1.008138  0.962264
# ...              ...       ...       ...        ...  ...       ...       ...
# 2021-07-07  1.377329  1.053793  0.988013   1.452434  ...  1.523486  2.052830
# 2021-07-08  1.361275  1.050818  0.972599   1.440850  ...  1.501337  1.932075
# 2021-07-12  1.395597  1.077593  1.000344   1.495153  ...  1.547080  1.905660
# 2021-07-13  1.394490  1.072965  0.994949   1.496239  ...  1.541302  1.826415
# 2021-07-14  1.400580  1.080237  0.990325   1.496601  ...  1.540339  1.766038
#
#             TCNO4.SA  PNVL4.SA  PCAR3.SA  CEAB3.SA  EUCA3.SA  BMGB4.SA  \
# Date
# 2020-06-24  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2020-06-25  1.027027  0.982292  1.027569  0.971845  0.968364  0.992565
# 2020-06-26  0.979730  1.034896  0.993216  0.953398  0.958182  0.944238
# 2020-06-29  1.013514  1.197916  1.052252  1.013592  0.981818  0.998141
# 2020-06-30  1.006757  1.262500  1.024538  1.000971  0.951273  1.003717
# ...              ...       ...       ...       ...       ...       ...
# 2021-07-07  3.074324  1.015929  4.305485  1.333010  0.770478  0.925553
# 2021-07-08  2.837838  1.016454  4.275498  1.319417  0.775652  0.900641
# 2021-07-12  2.844595  1.010682  4.274344  1.309709  0.757914  0.927469
# 2021-07-13  2.770270  1.022751  4.220136  1.302913  0.756806  0.937050
# 2021-07-14  2.722973  1.010157  4.225903  1.305825  0.767153  0.925553
#
#             CAMB3.SA     ^BVSP
# Date
# 2020-06-24  1.000000  1.000000
# 2020-06-25  0.967677  1.017017
# 2020-06-26  0.898990  0.994246
# 2020-06-29  0.858586  1.014389
# 2020-06-30  0.848485  1.007195
# ...              ...       ...
# 2021-07-07  1.155556  1.345868
# 2021-07-08  1.113131  1.329010
# 2021-07-12  1.125253  1.351961
# 2021-07-13  1.125253  1.358043
# 2021-07-14  1.141414  1.360575
#
# [260 rows x 241 columns]

# %%
drawdown = pd.DataFrame()
drawdown = drawdown.reindex_like(retornos_diarios, method = 'backfill')
#min(RBA['WEGE3.SA'].tail(tamanho_dias-200))
for a in acoes:
    t=0
    while t in range(tamanho_dias):
        drawdown[a].iloc[t]=(RBA[a].iloc[t]-min(RBA[a].tail(tamanho_dias-t)))/RBA[a].iloc[t]
        t+=1
drawdown_max = []
for a in acoes:
    drawdown_max.append(max(drawdown[a]))
drawdown_max = pd.Series(drawdown_max)
drawdown_max.index = acoes
drawdown_max = drawdown_max.rename('Drawdown')
drawdown_max
# Out:
# ALPA4.SA     0.223412
# ALUP11.SA    0.161770
# ABEV3.SA     0.212042
# BTOW3.SA     0.555556
# BBSE3.SA     0.261349
#                ...
# CEAB3.SA     0.289548
# EUCA3.SA     0.269980
# BMGB4.SA     0.290530
# CAMB3.SA     0.314516
# ^BVSP        0.120262
# Name: Drawdown, Length: 241, dtype: float64

# %% [markdown]
# ## Criando dataframe de risco

# %%
risco = pd.DataFrame()
risco = risco.append(desvio_padrao)
risco = risco.append(semivariancia)
risco = risco.append(drawdown_max)
risco = risco.append(Downside_Risk)
risco = risco.append(TEV)
risco = risco.append(beta)
del risco['^BVSP']
risco
# Out:
#                            AALR3.SA  ABCB4.SA  ABEV3.SA  AGRO3.SA  ALPA3.SA  \
# Desvio Padrão              0.030467  0.017553  0.021308  0.020895  0.023606
# Semivariância              0.019756  0.012086  0.014434  0.013852  0.016101
# Drawdown                   0.315079  0.219538  0.212042  0.222262  0.246166
# Downside Risk              0.017990  0.009513  0.010642  0.014834  0.016041
# Tracking Error Volatility  0.027903  0.014022  0.016676  0.022220  0.023643
# Beta de mercado            0.920874  0.813436  0.994627  0.339387  0.495093
#
#                            ALPA4.SA  ALUP11.SA  ALUP3.SA  ALUP4.SA  AMAR3.SA  \
# Desvio Padrão              0.024109   0.012940  0.015675  0.015716  0.033600
# Semivariância              0.016098   0.008658  0.011198  0.010480  0.021548
# Drawdown                   0.223412   0.161770  0.213147  0.160044  0.450597
# Downside Risk              0.014756   0.009601  0.013602  0.011491  0.018613
# Tracking Error Volatility  0.023110   0.013776  0.018071  0.017002  0.029642
# Beta de mercado            0.632591   0.437222  0.272782  0.381734  1.203665
#
#                            ...  VIVA3.SA  VIVR3.SA  VIVT3.SA  VLID3.SA  \
# Desvio Padrão              ...  0.025409  0.081233  0.014821  0.031443
# Semivariância              ...  0.016787  0.044282  0.010177  0.020587
# Drawdown                   ...  0.254922  0.657492  0.203140  0.419527
# Downside Risk              ...  0.013513  0.042150  0.011355  0.019640
# Tracking Error Volatility  ...  0.021743  0.081367  0.015379  0.028514
# Beta de mercado            ...  0.985939  0.438638  0.452660  0.993787
#
#                            VULC3.SA  VVAR3.SA  WEGE3.SA  WHRL3.SA  WHRL4.SA  \
# Desvio Padrão              0.023640  0.029197  0.025375  0.014026  0.014993
# Semivariância              0.016844  0.019934  0.016872  0.009436  0.010459
# Drawdown                   0.205186  0.484265  0.318399  0.124675  0.190476
# Downside Risk              0.012301  0.016829  0.014486  0.012206  0.012432
# Tracking Error Volatility  0.019786  0.024629  0.022360  0.016656  0.017453
# Beta de mercado            0.970429  1.191211  0.904563  0.273138  0.275627
#
#                            WIZS3.SA
# Desvio Padrão              0.035452
# Semivariância              0.023077
# Drawdown                   0.466431
# Downside Risk              0.022086
# Tracking Error Volatility  0.035251
# Beta de mercado            0.539970
#
# [6 rows x 240 columns]

# %%
media_dp = risco.loc['Desvio Padrão'].mean()
dp_dp = risco.loc['Desvio Padrão'].std()
media_sv = risco.loc['Semivariância'].mean()
dp_sv = risco.loc['Semivariância'].std()
media_drd = risco.loc['Drawdown'].mean()
dp_drd = risco.loc['Drawdown'].std()
media_dsr = risco.loc['Downside Risk'].mean()
dp_dsr = risco.loc['Downside Risk'].std()
media_tev = risco.loc['Tracking Error Volatility'].mean()
dp_tev = risco.loc['Tracking Error Volatility'].std()
media_beta = risco.loc['Beta de mercado'].mean()
dp_beta = risco.loc['Beta de mercado'].std()

# %%
risco_norm = pd.DataFrame()
dp_norm = (risco.loc['Desvio Padrão'] - media_dp) / dp_dp
dp_norm = dp_norm.rename('Desvio Padrão Normalizado')
risco_norm = risco_norm.append(dp_norm)
sv_norm = (risco.loc['Semivariância'] - media_sv) / dp_sv
sv_norm = sv_norm.rename('Semivariância Normalizada')
risco_norm = risco_norm.append(sv_norm)
drd_norm = (risco.loc['Drawdown'] - media_drd) / dp_drd
drd_norm = drd_norm.rename('Drawdown Normalizado')
risco_norm = risco_norm.append(drd_norm)
dsr_norm = (risco.loc['Downside Risk'] - media_dsr) / dp_dsr
dsr_norm = dsr_norm.rename('Downside Risk Normalizado')
risco_norm = risco_norm.append(dsr_norm)
tev_norm = (risco.loc['Tracking Error Volatility'] - media_tev) / dp_tev
tev_norm = tev_norm.rename('Tracking Error Volatility Normalizado')
risco_norm = risco_norm.append(tev_norm)
beta_norm = (risco.loc['Beta de mercado'] - media_beta) / dp_beta
beta_norm = beta_norm.rename('Beta de mercado Normalizado')
risco_norm = risco_norm.append(beta_norm)
risco_norm
# Out:
#                                        AALR3.SA  ABCB4.SA  ABEV3.SA  AGRO3.SA  \
# Desvio Padrão Normalizado              0.088211 -0.790517 -0.535005 -0.563139
# Semivariância Normalizada              0.284493 -0.879272 -0.523045 -0.611350
# Drawdown Normalizado                   0.154933 -0.651238 -0.714492 -0.628255
# Downside Risk Normalizado              0.280466 -1.106826 -0.921971 -0.235934
# Tracking Error Volatility Normalizado  0.037493 -0.879006 -0.703757 -0.337719
# Beta de mercado Normalizado            0.504794  0.179358  0.728200 -1.256572
#
#                                        ALPA3.SA  ALPA4.SA  ALUP11.SA  \
# Desvio Padrão Normalizado             -0.378664 -0.344436  -1.104405
# Semivariância Normalizada             -0.269972 -0.270495  -1.399362
# Drawdown Normalizado                  -0.426556 -0.618554  -1.138684
# Downside Risk Normalizado             -0.038481 -0.248764  -1.092456
# Tracking Error Volatility Normalizado -0.243763 -0.278940  -0.895258
# Beta de mercado Normalizado           -0.784926 -0.368435  -0.960221
#
#                                        ALUP3.SA  ALUP4.SA  AMAR3.SA  ...  \
# Desvio Padrão Normalizado             -0.918272 -0.915537  0.301355  ...
# Semivariância Normalizada             -1.014017 -1.122982  0.556429  ...
# Drawdown Normalizado                  -0.705164 -1.153246  1.298425  ...
# Downside Risk Normalizado             -0.437625 -0.783021  0.382586  ...
# Tracking Error Volatility Normalizado -0.611687 -0.682274  0.152347  ...
# Beta de mercado Normalizado           -1.458321 -1.128298  1.361389  ...
#
#                                        VIVA3.SA  VIVR3.SA  VIVT3.SA  VLID3.SA  \
# Desvio Padrão Normalizado             -0.256004  3.542402 -0.976398  0.154618
# Semivariância Normalizada             -0.165951  4.005912 -1.168893  0.410668
# Drawdown Normalizado                  -0.352673  3.044195 -0.789605  1.036255
# Downside Risk Normalizado             -0.452117  4.234632 -0.805287  0.550654
# Tracking Error Volatility Normalizado -0.369232  3.567594 -0.789416  0.077855
# Beta de mercado Normalizado            0.701882 -0.955931 -0.913459  0.725655
#
#                                        VULC3.SA  VVAR3.SA  WEGE3.SA  WHRL3.SA  \
# Desvio Padrão Normalizado             -0.376362  0.001783 -0.258306 -1.030513
# Semivariância Normalizada             -0.157249  0.311499 -0.153047 -1.281357
# Drawdown Normalizado                  -0.772342  1.582511  0.182945 -1.451686
# Downside Risk Normalizado             -0.650447  0.090613 -0.292974 -0.665988
# Tracking Error Volatility Normalizado -0.498401 -0.178631 -0.328467 -0.705083
# Beta de mercado Normalizado            0.654902  1.323666  0.455388 -1.457244
#
#                                        WHRL4.SA  WIZS3.SA
# Desvio Padrão Normalizado             -0.964713  0.427392
# Semivariância Normalizada             -1.126125  0.788418
# Drawdown Normalizado                  -0.896463  1.432030
# Downside Risk Normalizado             -0.629095  0.950861
# Tracking Error Volatility Normalizado -0.652474  0.522702
# Beta de mercado Normalizado           -1.449705 -0.648992
#
# [6 rows x 240 columns]

# %% [markdown]
# ## Criar ranking de risco

# %%
nota_risco = []
t=0
for a in (acoes_sem_bvsp):
    nota_risco.append(risco_norm[a].mean())
nota_risco = pd.Series(nota_risco)
nota_risco.index = acoes_sem_bvsp
nota_risco = nota_risco.sort_values(ascending = False)
nota_risco
# Out:
# VIVR3.SA     2.906467
# IGBR3.SA     2.796811
# JBDU3.SA     2.782061
# FHER3.SA     2.624798
# MWET4.SA     2.603291
#                ...
# TRPL3.SA    -1.130612
# BEES3.SA    -1.163370
# TAEE4.SA    -1.173106
# TAEE3.SA    -1.217662
# TAEE11.SA   -1.232600
# Length: 240, dtype: float64

# %%
ranking_risco = []
t=0
while t in range(len(nota_risco)):
    ranking_risco.append(t+1)
    t+=1
ranking_risco = pd.Series(ranking_risco)
ranking_risco.index = nota_risco.index
ranking_risco
# Out:
# VIVR3.SA       1
# IGBR3.SA       2
# JBDU3.SA       3
# FHER3.SA       4
# MWET4.SA       5
#             ...
# TRPL3.SA     236
# BEES3.SA     237
# TAEE4.SA     238
# TAEE3.SA     239
# TAEE11.SA    240
# Length: 240, dtype: int64

# %% [markdown]
# # Métricas de performance

# %% [markdown]
# ## Calcular Sharpe

# %%
#Várias métricas para Risk Free
ret_poup = 0.0072217938876129/100

CDI = 4.15/100
ret_nu = (1+CDI)**(1/360)-1

#Definir qual é o Risk Free
risk_free = ret_nu

# %%
sharpe = []
for a in acoes:
    sharpe.append((retornos_diarios_med[a]-1-risk_free)/desvio_padrao[a])
sharpe = pd.Series(sharpe)
sharpe.index = acoes
sharpe = sharpe.rename('Índice de Sharpe')
sharpe
# Out:
# ALPA4.SA     0.098551
# ALUP11.SA    0.040348
# ABEV3.SA     0.059688
# BTOW3.SA    -0.046423
# BBSE3.SA    -0.038072
#                ...
# CEAB3.SA     0.044948
# EUCA3.SA    -0.031691
# BMGB4.SA    -0.005388
# CAMB3.SA     0.028004
# ^BVSP        0.087388
# Name: Índice de Sharpe, Length: 241, dtype: float64

# %% [markdown]
# ## Calcular Sortino (semivariância)

# %%
sortino_sv = []
for a in acoes:
    sortino_sv.append((retornos_diarios_med[a]-1-risk_free)/semivariancia[a])
sortino_sv = pd.Series(sortino_sv)
sortino_sv.index = acoes
sortino_sv = sortino_sv.rename('Sortino (semivariância)')
sortino_sv
# Out:
# ALPA4.SA     0.147594
# ALUP11.SA    0.060302
# ABEV3.SA     0.088117
# BTOW3.SA    -0.071423
# BBSE3.SA    -0.053376
#                ...
# CEAB3.SA     0.068117
# EUCA3.SA    -0.052750
# BMGB4.SA    -0.008408
# CAMB3.SA     0.042729
# ^BVSP        0.118396
# Name: Sortino (semivariância), Length: 241, dtype: float64

# %% [markdown]
# ## Calcular Sortino (Downside Risk)

# %%
sortino_dsr = []
for a in acoes:
    sortino_dsr.append((retornos_diarios_med[a]-retornos_diarios_med['^BVSP'])/Downside_Risk[a])
sortino_dsr = pd.Series(sortino_dsr)
sortino_dsr.index = acoes
sortino_dsr = sortino_dsr.rename('Sortino (Downside Risk)')
sortino_dsr
# Out:
# <ipython-input-38-bd5fc9f26ccd>:3: RuntimeWarning: invalid value encountered in double_scalars
#   sortino_dsr.append((retornos_diarios_med[a]-retornos_diarios_med['^BVSP'])/Downside_Risk[a])
# ALPA4.SA     0.082038
# ALUP11.SA   -0.067010
# ABEV3.SA     0.009998
# BTOW3.SA    -0.126120
# BBSE3.SA    -0.192238
#                ...
# CEAB3.SA     0.012261
# EUCA3.SA    -0.107923
# BMGB4.SA    -0.093420
# CAMB3.SA    -0.019662
# ^BVSP             NaN
# Name: Sortino (Downside Risk), Length: 241, dtype: float64

# %% [markdown]
# ## Calcular Treynor

# %%
Treynor = []
for a in acoes:
    Treynor.append((retornos_diarios_med[a]-1-risk_free)/beta[a])
Treynor = pd.Series(Treynor)
Treynor.index = acoes
Treynor = Treynor.rename('Índice de Treynor')
Treynor
# Out:
# ALPA4.SA     0.003756
# ALUP11.SA    0.001194
# ABEV3.SA     0.001279
# BTOW3.SA    -0.001847
# BBSE3.SA    -0.000718
#                ...
# CEAB3.SA     0.001403
# EUCA3.SA    -0.004386
# BMGB4.SA    -0.000150
# CAMB3.SA     0.001614
# ^BVSP        0.001165
# Name: Índice de Treynor, Length: 241, dtype: float64

# %% [markdown]
# ## Calcular Calmar

# %%
Calmar = []
for a in acoes:
    Calmar.append((retornos_diarios_med[a]-1-risk_free)/drawdown_max[a])
Calmar = pd.Series(Calmar)
Calmar.index = acoes
Calmar = Calmar.rename('Índice de Calmar')
Calmar
# Out:
# ALPA4.SA     0.010635
# ALUP11.SA    0.003227
# ABEV3.SA     0.005998
# BTOW3.SA    -0.002580
# BBSE3.SA    -0.002293
#                ...
# CEAB3.SA     0.004802
# EUCA3.SA    -0.003017
# BMGB4.SA    -0.000444
# CAMB3.SA     0.002544
# ^BVSP        0.009691
# Name: Índice de Calmar, Length: 241, dtype: float64

# %% [markdown]
# ## Calcular Information Ratio

# %%
InfRatio = []
for a in acoes:
    InfRatio.append((retornos_diarios_med[a]-retornos_diarios_med['^BVSP'])/TEV[a])
InfRatio = pd.Series(InfRatio)
InfRatio.index = acoes
InfRatio = InfRatio.rename('Information Ratio')
InfRatio
# Out:
# <ipython-input-41-9c53ffdc9d93>:3: RuntimeWarning: invalid value encountered in double_scalars
#   InfRatio.append((retornos_diarios_med[a]-retornos_diarios_med['^BVSP'])/TEV[a])
# ALPA4.SA     0.052381
# ALUP11.SA   -0.046700
# ABEV3.SA     0.006381
# BTOW3.SA    -0.088871
# BBSE3.SA    -0.155597
#                ...
# CEAB3.SA     0.008045
# EUCA3.SA    -0.071245
# BMGB4.SA    -0.061332
# CAMB3.SA    -0.012781
# ^BVSP             NaN
# Name: Information Ratio, Length: 241, dtype: float64

# %% [markdown]
# ## Calcular M2

# %%
M2 = []
for a in acoes:
    M2.append(sharpe[a]*desvio_padrao['^BVSP']+risk_free)
M2 = pd.Series(M2)
M2.index = acoes
M2 = M2.rename('M2')
M2
# Out:
# ALPA4.SA     0.001427
# ALUP11.SA    0.000651
# ABEV3.SA     0.000909
# BTOW3.SA    -0.000506
# BBSE3.SA    -0.000395
#                ...
# CEAB3.SA     0.000712
# EUCA3.SA    -0.000310
# BMGB4.SA     0.000041
# CAMB3.SA     0.000486
# ^BVSP        0.001278
# Name: M2, Length: 241, dtype: float64

# %% [markdown]
# ## DataFrame de performance

# %%
perf = pd.DataFrame()
perf = perf.append(sharpe)
perf = perf.append(sortino_sv)
perf = perf.append(sortino_dsr)
perf = perf.append(Treynor)
perf = perf.append(Calmar)
perf = perf.append(InfRatio)
perf = perf.append(M2)
del perf['^BVSP']

# %%
media_sharpe = perf.loc['Índice de Sharpe'].mean()
dp_sharpe = perf.loc['Índice de Sharpe'].std()
media_sort_sv = perf.loc['Sortino (semivariância)'].mean()
dp_sort_sv = perf.loc['Sortino (semivariância)'].std()
media_sort_dsr = perf.loc['Sortino (Downside Risk)'].mean()
dp_sort_dsr = perf.loc['Sortino (Downside Risk)'].std()
media_treynor = perf.loc['Índice de Treynor'].mean()
dp_treynor = perf.loc['Índice de Treynor'].std()
media_calmar = perf.loc['Índice de Calmar'].mean()
dp_calmar = perf.loc['Índice de Calmar'].std()
media_ir = perf.loc['Information Ratio'].mean()
dp_ir = perf.loc['Information Ratio'].std()
media_m2 = perf.loc['M2'].mean()
dp_m2 = perf.loc['M2'].std()

# %%
perf_norm = pd.DataFrame()
#sharpe
sharpe_norm = (perf.loc['Índice de Sharpe'] - media_sharpe) / dp_sharpe
sharpe_norm = sharpe_norm.rename('Sharpe Normalizado')
perf_norm = perf_norm.append(sharpe_norm)
#sortino sv
ssv_norm = (perf.loc['Sortino (semivariância)'] - media_sort_sv) / dp_sort_sv
ssv_norm = ssv_norm.rename('Sortino (semivariância) Normalizado')
perf_norm = perf_norm.append(ssv_norm)
#sortino dsr
sdsr_norm = (perf.loc['Sortino (Downside Risk)'] - media_sort_dsr) / dp_sort_dsr
sdsr_norm = sdsr_norm.rename('Sortino (Downside Risk) Normalizado')
perf_norm = perf_norm.append(sdsr_norm)
#Treynor
treynor_norm = (perf.loc['Índice de Treynor'] - media_treynor) / dp_treynor
treynor_norm = treynor_norm.rename('Treynor Normalizado')
perf_norm = perf_norm.append(treynor_norm)
#Calmar
calmar_norm = (perf.loc['Índice de Calmar'] - media_calmar) / dp_calmar
calmar_norm = calmar_norm.rename('Calmar Normalizado')
perf_norm = perf_norm.append(calmar_norm)
#IR
ir_norm = (perf.loc['Information Ratio'] - media_ir) / dp_ir
ir_norm = ir_norm.rename('Information Ratio Normalizado')
perf_norm = perf_norm.append(ir_norm)
#M2
m2_norm = (perf.loc['M2'] - media_m2) / dp_m2
m2_norm = sharpe_norm.rename('M2 Normalizado')
perf_norm = perf_norm.append(m2_norm)
#dataframe normalizado
perf_norm
# Out:
#                                      AALR3.SA  ABCB4.SA  ABEV3.SA  AGRO3.SA  \
# Sharpe Normalizado                  -0.487073 -0.349481  0.124217  0.512540
# Sortino (semivariância) Normalizado -0.505746 -0.403184  0.033030  0.411488
# Sortino (Downside Risk) Normalizado -0.386584 -0.716468 -0.070878  0.175914
# Treynor Normalizado                 -0.204020 -0.207524 -0.178242  0.004971
# Calmar Normalizado                  -0.547485 -0.511191 -0.084852  0.137555
# Information Ratio Normalizado       -0.311192 -0.702701  0.031986  0.314766
# M2 Normalizado                      -0.487073 -0.349481  0.124217  0.512540
#
#                                      ALPA3.SA  ALPA4.SA  ALUP11.SA  ALUP3.SA  \
# Sharpe Normalizado                   0.968918  0.758438  -0.191391 -1.121687
# Sortino (semivariância) Normalizado  0.786392  0.628281  -0.245348 -1.082228
# Sortino (Downside Risk) Normalizado  0.620815  0.541590  -0.725590 -1.047557
# Treynor Normalizado                  0.013233 -0.060693  -0.182255 -0.284342
# Calmar Normalizado                   0.478845  0.472548  -0.417912 -0.953150
# Information Ratio Normalizado        0.831166  0.693175  -0.730979 -1.194429
# M2 Normalizado                       0.968918  0.758438  -0.191391 -1.121687
#
#                                      ALUP4.SA  AMAR3.SA  ...  VIVA3.SA  \
# Sharpe Normalizado                   0.268605 -0.511443  ...  0.354209
# Sortino (semivariância) Normalizado  0.179761 -0.525245  ...  0.268795
# Sortino (Downside Risk) Normalizado -0.221253 -0.369962  ...  0.290336
# Treynor Normalizado                 -0.105032 -0.211452  ... -0.148694
# Calmar Normalizado                   0.003122 -0.620008  ...  0.078136
# Information Ratio Normalizado       -0.134426 -0.286999  ...  0.409137
# M2 Normalizado                       0.268605 -0.511443  ...  0.354209
#
#                                      VIVR3.SA  VIVT3.SA  VLID3.SA  VULC3.SA  \
# Sharpe Normalizado                   0.311748 -1.154993 -0.788456  1.285629
# Sortino (semivariância) Normalizado  0.457954 -1.121387 -0.791352  0.989097
# Sortino (Downside Risk) Normalizado  0.775308 -1.235957 -0.609169  1.176591
# Treynor Normalizado                  0.386587 -0.267971 -0.233272 -0.087659
# Calmar Normalizado                   0.251266 -0.969884 -0.771993  1.006424
# Information Ratio Normalizado        0.755811 -1.408008 -0.587587  1.340825
# M2 Normalizado                       0.311748 -1.154993 -0.788456  1.285629
#
#                                      VVAR3.SA  WEGE3.SA  WHRL3.SA  WHRL4.SA  \
# Sharpe Normalizado                  -0.635512  0.345980 -0.049050  0.316606
# Sortino (semivariância) Normalizado -0.656324  0.254091 -0.118859  0.176599
# Sortino (Downside Risk) Normalizado -0.550914  0.251408 -0.488242 -0.220023
# Treynor Normalizado                 -0.223644 -0.141379 -0.119349 -0.054424
# Calmar Normalizado                  -0.710696 -0.103879 -0.142273 -0.129560
# Information Ratio Normalizado       -0.516079  0.386361 -0.471517 -0.136969
# M2 Normalizado                      -0.635512  0.345980 -0.049050  0.316606
#
#                                      WIZS3.SA
# Sharpe Normalizado                   0.255133
# Sortino (semivariância) Normalizado  0.192202
# Sortino (Downside Risk) Normalizado  0.319542
# Treynor Normalizado                 -0.027968
# Calmar Normalizado                  -0.187224
# Information Ratio Normalizado        0.443857
# M2 Normalizado                       0.255133
#
# [7 rows x 240 columns]

# %% [markdown]
# ## Criar ranking de performance

# %%
nota_perf = []
t=0
for a in (acoes_sem_bvsp):
    nota_perf.append(perf_norm[a].mean())
nota_perf = pd.Series(nota_perf)
nota_perf.index = acoes_sem_bvsp
nota_perf = nota_perf.sort_values(ascending = False)
nota_perf.head(10)
# Out:
# CRPG5.SA     3.029924
# UNIP3.SA     2.881249
# JBDU3.SA     2.682044
# FRAS3.SA     2.418873
# UNIP6.SA     2.218862
# BIDI11.SA    2.166930
# TESA3.SA     2.105372
# CSNA3.SA     1.883418
# PCAR3.SA     1.787636
# PTBL3.SA     1.778851
# dtype: float64

# %%
ranking_perf = []
t=0
while t in range(len(nota_perf)):
    ranking_perf.append(t+1)
    t+=1
ranking_perf = pd.Series(ranking_perf)
ranking_perf.index = nota_perf.index

# %% [markdown]
# # Ranking Geral

# %%
base_dados = pd.read_excel(r'C:\Users\perdi\Investimentos\Dados\Dados_Cadastrais.xlsx', index_col=0)
base_dados["Posição no Ranking de Performance"] = ranking_perf
base_dados["Posição no Ranking de Risco"] = ranking_risco
base_dados["Nota Geral"] = ranking_risco / ranking_perf
base_dados
# Out:
#                                           Nome Completo Tipo da ação  \
# Código de negociação
# ALPA4.SA                                ALPARGATAS S.A.           PN
# ALUP11.SA                       ALUPAR INVESTIMENTO S/A         Unit
# ABEV3.SA                                     AMBEV S.A.           ON
# BTOW3.SA                        B2W - COMPANHIA DIGITAL           ON
# BBSE3.SA               BB SEGURIDADE PARTICIPAÇÕES S.A.           ON
# ...                                                 ...          ...
# PCAR3.SA                 CIA BRASILEIRA DE DISTRIBUICAO           ON
# CEAB3.SA                                      CEA MODAS           ON
# EUCA3.SA              EUCATEX S.A. INDUSTRIA E COMERCIO           ON
# BMGB4.SA                                      BANCO BMG           ON
# CAMB3.SA                                   CAMBUCI S.A.           ON
#
#                      Nacionalidade Nível de governança      Setor Econômico  \
# Código de negociação
# ALPA4.SA                  Nacional     Bovespa Nível 1      Consumo cíclico
# ALUP11.SA                 Nacional     Bovespa Nível 2    Utilidade Pública
# ABEV3.SA                  Nacional          Não consta  Consumo não Cíclico
# BTOW3.SA                  Nacional        Novo Mercado      Consumo cíclico
# BBSE3.SA                  Nacional        Novo Mercado  Financeiro e Outros
# ...                            ...                 ...                  ...
# PCAR3.SA                  Nacional     Bovespa Nível 1  Consumo não Cíclico
# BMGB4.SA                                    123.0    0.627551
# CAMB3.SA                                     93.0    0.650350
#
# [255 rows x 14 columns]

# %% [markdown]
# ## Filtrando ações indesejadas

# %%
base_filtrada = base_dados.copy(deep=True)
#Retirar ações no top 20 de risco e ações em recuperação judicial:
for acao in base_filtrada.index:
    if base_filtrada.loc[acao]['Posição no Ranking de Risco'] <= 20:
        print(f'{acao} entre as 20 mais arriscadas. Retirando ela da base cadastral...')
        base_filtrada.drop(index=acao, inplace=True)
for acao in base_filtrada.index:
    if base_filtrada.loc[acao]['Em Recuperação Judicial'] == "Sim":
        print(f'{acao} está em recuperação judicial. Retirando ela da base cadastral...')
        base_filtrada.drop(index=acao, inplace=True)
# Out:
# ETER3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# BBRK3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# VIVR3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# LPSB3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# FHER3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# TPIS3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# LUPA3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# ATOM3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# AZEV4.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# RCSL4.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# JBDU4.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# SLED3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# IGBR3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# CTSA3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# JBDU3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# RCSL3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# PSVM11.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# MWET4.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# TCNO3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# TCNO4.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# OIBR3.SA está em recuperação judicial. Retirando ela da base cadastral...
# OIBR4.SA está em recuperação judicial. Retirando ela da base cadastral...
# RPMG3.SA está em recuperação judicial. Retirando ela da base cadastral...
# OSXB3.SA está em recuperação judicial. Retirando ela da base cadastral...

# %% [markdown]
# ## Filtro de segmento

# %%
filtro_seg=base_filtrada.sort_values(by="Nota Geral",ascending=False).copy(deep=True)    
filtro_seg.reset_index(inplace=True)
i=0
while i in filtro_seg.index:
    segmento=filtro_seg.loc[i]['Segmento']
    #print(i)
    #print('ação atual')
    #print(base_rankeada.iloc[i]['Código de negociação'])
    #print('ações seguintes')
    j=i+1
    while j in range(len(filtro_seg.index)):
        #print(j)
        #print(base_rankeada.iloc[j]['Código de negociação'])
        if filtro_seg.loc[j]['Segmento'] == segmento:
            #print(str(base_rankeada.loc[i]['Código de negociação']))
            #print(str(base_rankeada.loc[j]['Código de negociação']))
            filtro_seg.drop([j], inplace=True)
            filtro_seg.reset_index(drop = True, inplace=True)
            #print(range(len(base_rankeada.index)))
        j+=1
    i+=1
    #print('acabou o loop da ' + str(base_rankeada.loc[i]['Código de negociação']))
filtro_seg.set_index('Código de negociação', inplace=True)

# %% [markdown]
# ## Top 20 após filtragem

# %%
#Gráfico de RBA do top 20 provisório
RBA_top20 = pd.DataFrame()
for acao in base_filtrada.sort_values(by="Nota Geral",ascending=False).head(20).index:
    RBA_top20[acao]=RBA[acao]
RBA_top20.plot(figsize=(15,10), colormap='winter')
plt.show()
#Gráfico de correlação do top 20 provisório
ret_filtro = retornos_diarios.copy(deep=True)
for acao in ret_filtro.columns:
    if acao not in filtro_seg.sort_values(by="Nota Geral",ascending=False).head(20).index:
        ret_filtro.drop(columns=acao,inplace=True)
plt.figure(figsize=(16,8))
sns.heatmap(ret_filtro.corr(), annot =True, cmap="Wistia")
plt.show()
#Dados cadastrais do top 20 provisório
filtro_seg.sort_values(
    by="Nota Geral",ascending=False).head(20).drop(
# ENEV3.SA                                           60.0
# FESA4.SA                                           21.0
# FRAS3.SA                                            4.0
# KLBN3.SA                                           75.0
# MTSA4.SA                                           13.0
# PCAR3.SA                                            9.0
# PTBL3.SA                                           10.0
# SHUL4.SA                                           33.0
# SMTO3.SA                                           43.0
# TAEE11.SA                                          35.0
# TESA3.SA                                            7.0
# UNIP3.SA                                            2.0
# VALE3.SA                                           14.0
# VULC3.SA                                           31.0
#
#                       Posição no Ranking de Risco  Nota Geral
# Código de negociação
# ARZZ3.SA                                    187.0    9.842105
# BIDI11.SA                                    47.0    7.833333
# BRAP4.SA                                    181.0   11.312500
# CRPG5.SA                                    214.0  214.000000
# CSNA3.SA                                     75.0    9.375000
# DTEX3.SA                                    146.0    2.607143
# ENEV3.SA                                    165.0    2.750000
# FESA4.SA                                    133.0    6.333333
# FRAS3.SA                                    224.0   56.000000
# KLBN3.SA                                    204.0    2.720000
# MTSA4.SA                                    190.0   14.615385
# PCAR3.SA                                     29.0    3.222222
# PTBL3.SA                                     56.0    5.600000
# SHUL4.SA                                    188.0    5.696970
# SMTO3.SA                                    171.0    3.976744
# TAEE11.SA                                   240.0    6.857143
# TESA3.SA                                    138.0   19.714286
# UNIP3.SA                                    230.0  115.000000
# VALE3.SA                                    203.0   14.500000
# VULC3.SA                                    144.0    4.645161

# %% [markdown]
# # Personalizar top 20

# %% [markdown]
# ## Filtro manual

# %%
#insira na lista abaixo os tickers que deseja retirar do top 20
top20 = filtro_seg.copy(deep=True)
lista = ['VALE3.SA', 'CSNA3.SA']
for acao in lista:
    top20.drop(index=acao,inplace=True)

# %%
#Visualizar dados
top20.head(20).drop(
    columns=['Nacionalidade','Participação (%) no IBOVESPA','Em Recuperação Judicial'])
# Out:
#                                                       Nome Completo  \
# Código de negociação
# CRPG5.SA                           CRISTAL PIGMENTOS DO BRASIL S.A.
# UNIP3.SA                                     UNIPAR CARBOCLORO S.A.
# FRAS3.SA                                               FRAS-LE S.A.
# TESA3.SA                                      TERRA SANTA AGRO S.A.
# MTSA4.SA                          METISA METALURGICA TIMBOENSE S.A.
# BRAP4.SA                                             BRADESPAR S.A.
# ARZZ3.SA                           AREZZO INDÚSTRIA E COMÉRCIO S.A.
# BIDI11.SA                                          BANCO INTER S.A.
# TAEE11.SA             TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.
# FESA4.SA                         CIA FERRO LIGAS DA BAHIA - FERBASA
# SHUL4.SA                                                SCHULZ S.A.
# PTBL3.SA                                            PORTOBELLO S.A.
# VULC3.SA                                     VULCABRAS/AZALEIA S.A.
# SMTO3.SA                                          SAO MARTINHO S.A.
# PCAR3.SA                             CIA BRASILEIRA DE DISTRIBUICAO
# ENEV3.SA                                                      ENEVA
# KLBN3.SA                                                KLABIN S.A.
# DTEX3.SA                                               DURATEX S.A.
# GRND3.SA                                              GRENDENE S.A.
# KEPL3.SA                                          KEPLER WEBER S.A.
#
#                      Tipo da ação Nível de governança  \
# Código de negociação
# CRPG5.SA                      PNA          Não consta
# UNIP3.SA                                                   1       Privada
# FRAS3.SA                                                   1       Privada
# TESA3.SA                                                   1       Privada
# MTSA4.SA                                                   1       Privada
# BRAP4.SA                                                   1       Privada
# ARZZ3.SA                                                   1       Privada
# BIDI11.SA                                                  1       Privada
# TAEE11.SA                                                  1       Privada
# FESA4.SA                                                   1       Privada
# SHUL4.SA                                                   1       Privada
# PTBL3.SA                                                   1       Privada
# VULC3.SA                                                   1       Privada
# SMTO3.SA                                                   1       Privada
# PCAR3.SA                                                   1       Privada
# ENEV3.SA                                                   1       Privada
# KLBN3.SA                                                   1       Privada
# DTEX3.SA                                                   1       Privada
# GRND3.SA                                                   1       Privada
# KEPL3.SA                                                   1       Privada
#
#                       Posição no Ranking de Performance  \
# Código de negociação
# CRPG5.SA                                            1.0
# UNIP3.SA                                            2.0
# FRAS3.SA                                            4.0
# TESA3.SA                                            7.0
# MTSA4.SA                                           13.0
# BRAP4.SA                                           16.0
# ARZZ3.SA                                           19.0
# BIDI11.SA                                           6.0
# TAEE11.SA                                          35.0
# FESA4.SA                                           21.0
# SHUL4.SA                                           33.0
# PTBL3.SA                                           10.0
# VULC3.SA                                           31.0
# SMTO3.SA                                           43.0
# PCAR3.SA                                            9.0
# ENEV3.SA                                           60.0
# KLBN3.SA                                           75.0
# DTEX3.SA                                           56.0
# GRND3.SA                                           68.0
# KEPL3.SA                                           76.0
#
#                       Posição no Ranking de Risco  Nota Geral
# Código de negociação
# CRPG5.SA                                    214.0  214.000000
# UNIP3.SA                                    230.0  115.000000
# FRAS3.SA                                    224.0   56.000000
# TESA3.SA                                    138.0   19.714286
# MTSA4.SA                                    190.0   14.615385
# BRAP4.SA                                    181.0   11.312500
# ARZZ3.SA                                    187.0    9.842105
# BIDI11.SA                                    47.0    7.833333
# TAEE11.SA                                   240.0    6.857143
# FESA4.SA                                    133.0    6.333333
# SHUL4.SA                                    188.0    5.696970
# PTBL3.SA                                     56.0    5.600000
# VULC3.SA                                    144.0    4.645161
# SMTO3.SA                                    171.0    3.976744
# PCAR3.SA                                     29.0    3.222222
# ENEV3.SA                                    165.0    2.750000
# KLBN3.SA                                    204.0    2.720000
# DTEX3.SA                                    146.0    2.607143
# GRND3.SA                                    175.0    2.573529
# KEPL3.SA                                    194.0    2.552632

# %% [markdown]
# ## Preview dos ativos selecionados

# %%
RBA_top20 = pd.DataFrame()
for acao in top20.head(20).index:
    RBA_top20[acao]=RBA[acao]
RBA_top20.plot(figsize=(16,10), colormap='winter')
plt.show()
ret_top20 = retornos_diarios.copy(deep=True)
for acao in ret_top20.columns:
    if acao not in top20.head(20).index:
        ret_top20.drop(columns=acao,inplace=True)
plt.figure(figsize=(16,10))
sns.heatmap(ret_top20.corr(), annot =True, cmap="Wistia")
plt.show()

# %% [markdown]
# # Exportar resultados da análise

# %%
top20_final=top20.head(18)
top20_final.drop(columns=['Em Recuperação Judicial','Presença nos pregões do último ano (%)','Participação (%) no IBOVESPA'])
# Out:
#                                                       Nome Completo  \
# Código de negociação
# ENEV3.SA                    Utilidade Pública               Energia Elétrica
# KLBN3.SA                    Materiais Básicos                Madeira e Papel
# DTEX3.SA                    Materiais Básicos                Madeira e Papel
#
#                                                   Segmento PJ de direito  \
# Código de negociação
# CRPG5.SA                                 Químicos Diversos       Privada
# UNIP3.SA                                     Petroquímicos       Privada
# FRAS3.SA                               Material Rodoviário       Privada
# TESA3.SA                                       Agricultura       Privada
# MTSA4.SA              Máq. e Equip. Construção e Agrícolas       Privada
# BRAP4.SA                           Holdings Diversificadas       Privada
# ARZZ3.SA                     Tecidos, Vestuário e Calçados       Privada
# BIDI11.SA                                           Bancos       Privada
# TAEE11.SA                                 Energia Elétrica       Privada
# FESA4.SA                                        Siderurgia       Privada
# SHUL4.SA                   Motores , Compressores e Outros       Privada
# PTBL3.SA                           Materiais de Construção       Privada
# VULC3.SA                                          Calçados       Privada
# SMTO3.SA                                   Açucar e Alcool       Privada
# PCAR3.SA                                         Alimentos       Privada
# ENEV3.SA                                  Energia Elétrica       Privada
# KLBN3.SA                                  Papel e Celulose       Privada
# DTEX3.SA                                           Madeira       Privada
#
#                       Posição no Ranking de Performance  \
# Código de negociação
# CRPG5.SA                                            1.0
# UNIP3.SA                                            2.0
# FRAS3.SA                                            4.0
# TESA3.SA                                            7.0
# MTSA4.SA                                           13.0
# BRAP4.SA                                           16.0
# ARZZ3.SA                                           19.0
# BIDI11.SA                                           6.0
# TAEE11.SA                                          35.0
# FESA4.SA                                           21.0
# SHUL4.SA                                           33.0
# PTBL3.SA                                           10.0
# VULC3.SA                                           31.0
# SMTO3.SA                                           43.0
# PCAR3.SA                                            9.0
# ENEV3.SA                                           60.0
# KLBN3.SA                                           75.0
# DTEX3.SA                                           56.0
#
#                       Posição no Ranking de Risco  Nota Geral
# Código de negociação
# CRPG5.SA                                    214.0  214.000000
# UNIP3.SA                                    230.0  115.000000
# FRAS3.SA                                    224.0   56.000000
# TESA3.SA                                    138.0   19.714286
# MTSA4.SA                                    190.0   14.615385
# BRAP4.SA                                    181.0   11.312500
# ARZZ3.SA                                    187.0    9.842105
# BIDI11.SA                                    47.0    7.833333
# TAEE11.SA                                   240.0    6.857143
# FESA4.SA                                    133.0    6.333333
# SHUL4.SA                                    188.0    5.696970
# PTBL3.SA                                     56.0    5.600000
# VULC3.SA                                    144.0    4.645161
# SMTO3.SA                                    171.0    3.976744
# PCAR3.SA                                     29.0    3.222222
# ENEV3.SA                                    165.0    2.750000
# KLBN3.SA                                    204.0    2.720000
# DTEX3.SA                                    146.0    2.607143

# %% [markdown]
# ## Série histórica de cotações do top 20

# %%
dados_top20 = dados.copy(deep=True)
for acao in dados_top20.columns:
    if acao not in top20_final.index:
        dados_top20.drop(columns=acao,inplace=True)
dados_top20.to_excel('dados_top20.xlsx')

# %% [markdown]
# ## Métricas de ganho, risco e performance do Top 20

# %%
metricas_top20 = pd.concat([retorno,perf,risco])
for acao in metricas_top20.columns:
    if acao not in top20_final.index:
        metricas_top20.drop(columns=acao,inplace=True)
metricas_top20.to_excel('metricas_top20.xlsx')
